# %%
# Uploads the dataset into google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/Deep Learning'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 10.2 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# %%
model = YOLO('yolov8.yaml')

results = model.train(data = os.path.join(ROOT_DIR, 'data.yaml'), epochs = 20)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics YOLOv8.1.33 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Downloads the generated files into google drive
# !scp -r /content/runs '/content/gdrive/My Drive/Deep Learning'
